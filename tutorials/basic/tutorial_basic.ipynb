# %%
import os
import sys
import numpy as np
import ipyparallel as ipp

# Import library specific modules
sys.path.append(os.path.join("../../"))
from pyparsvd.parsvd_parallel import ParSVD_Parallel
from pyparsvd.parsvd_serial   import ParSVD_Serial
c = ipp.Client(profile='mpi')
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# <ipython-input-3-be68b8cfce81> in <module>
#       8 from pyparsvd.parsvd_parallel import ParSVD_Parallel
#       9 from pyparsvd.parsvd_serial   import ParSVD_Serial
# ---> 10 c = ipp.Client(profile='mpi')
#
# /usr/local/lib/python3.8/site-packages/ipyparallel/client/client.py in __init__(self, url_file, profile, profile_dir, ipython_dir, context, debug, sshserver, sshkey, password, paramiko, timeout, cluster_id, **extra_args)
#     517
#     518         try:
# --> 519             self._connect(sshserver, ssh_kwargs, timeout)
#     520         except:
#     521             self.close(linger=0)
#
# /usr/local/lib/python3.8/site-packages/ipyparallel/client/client.py in _connect(self, sshserver, ssh_kwargs, timeout)
#     636         evts = poller.poll(timeout*1000)
#     637         if not evts:
# --> 638             raise error.TimeoutError("Hub connection request timed out")
#     639         idents, msg = self.session.recv(self._query_socket, mode=0)
#     640         if self.debug:
#
# TimeoutError: Hub connection request timed out

# %%
# Path to data
path = os.path.join('./data/')

# Construct SVD objects
SerSVD = ParSVD_Serial(K=10, ff=1.0)
ParSVD = ParSVD_Parallel(K=10, ff=1.0, low_rank=True)
print(view)

# %%
# Serial data
# -------------
initial_data_ser = np.load(os.path.join(path, 'Batch_0_data.npy'))
new_data_ser = np.load(os.path.join(path, 'Batch_1_data.npy'))
newer_data_ser = np.load(os.path.join(path, 'Batch_2_data.npy'))
newest_data_ser = np.load(os.path.join(path, 'Batch_3_data.npy'))

# %%
# Do first modal decomposition
SerSVD.initialize(initial_data_ser)

# %%
# Incorporate new data
SerSVD.incorporate_data(new_data_ser)
SerSVD.incorporate_data(newer_data_ser)
SerSVD.incorporate_data(newest_data_ser)

# %%
# Parallel data
# -------------
initial_data_par = np.load(os.path.join(path, 'points_rank_' + str(ParSVD.rank) + '_batch_0.npy'))
new_data_par = np.load(os.path.join(path, 'points_rank_' + str(ParSVD.rank) + '_batch_1.npy'))
newer_data_par = np.load(os.path.join(path, 'points_rank_' + str(ParSVD.rank) + '_batch_2.npy'))
newest_data_par = np.load(os.path.join(path, 'points_rank_' + str(ParSVD.rank) + '_batch_3.npy'))

# %%
# Do first modal decomposition
ParSVD.initialize(initial_data_par)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-89c4da3e4618> in <module>
#       1 # Do first modal decomposition
# ----> 2 ParSVD.initialize(initial_data_par)
#
# ~/GIT-GM/PyParSVD-Mengaldo/pyparsvd/parsvd_parallel.py in initialize(self, A)
#      25
#      26         def initialize(self, A):
# ---> 27                 self.ulocal, self._singular_values = self.parallel_svd(A)
#      28                 self._gather_modes()
#      29
#
# ~/GIT-GM/PyParSVD-Mengaldo/pyparsvd/parsvd_parallel.py in parallel_svd(self, A)
#     134                 phi_local = []
#     135                 for mode in range(self._K):
# --> 136                         phi_temp = 1.0 / s[mode] * np.matmul(A, x[:,mode:mode+1])
#     137                         phi_local.append(phi_temp)
#     138
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
# Incorporate new data
ParSVD.incorporate_data(new_data_par)
ParSVD.incorporate_data(newer_data_par)
ParSVD.incorporate_data(newest_data_par)

# %%
if ParSVD.rank == 0:

	# Save results
	SerSVD.save()
	ParSVD.save()

	# Visualize modes
	SerSVD.plot_1D_modes(filename='serial_1d_modes.png')
	ParSVD.plot_1D_modes(filename='parallel_1d_modes.png')
